# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure


#matplotlib.rcParams['figure, figuresize'] = (12,8)
# Loading data
df=pd.read_csv("movies.csv")

# %%
df.head(50)
# Out:
#                                               name rating      genre  year  \
# 0                                      The Shining      R      Drama  1980
# 1                                  The Blue Lagoon      R  Adventure  1980
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                        Airplane!     PG     Comedy  1980
# 4                                       Caddyshack      R     Comedy  1980
# 5                                  Friday the 13th      R     Horror  1980
# 6                               The Blues Brothers      R     Action  1980
# 7                                      Raging Bull      R  Biography  1980
# 8                                      Superman II     PG     Action  1980
# 9                                  The Long Riders      R  Biography  1980
# 10                           Any Which Way You Can     PG     Action  1980
# ...

# %%
#Checking if there is any missing values
#Printing column and percent missing 
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
#Checking data types
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#Changing to more suitable datatypes
# Drop rows with NaNs in specified columns
df = df.dropna(subset=['budget', 'gross','rating'])
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
#Checking if there is any missing values
#Printing column and percent missing 
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 0%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 0%
# gross - 0%
# company - 0%
# runtime - 0%

# %%
df = df.sort_values(by=['gross'],ascending = False , inplace = False)

# %%
#pd.set_option('display.max_rows',None)

# %%
# Drop any duplicates
df['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 3330                          Zucker Brothers Productions
# 520                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 3698                              Zentropa Entertainments
# 1180                                 Zenith Entertainment
# 5180                                      Zazen Produções
# 1321                             Zanuck/Brown Productions
# 1329                          Zacharias-Buhai Productions
# 789                             Young Sung Production Co.
# 5125                           Young Hannibal Productions
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# budget have high correlation wiht gross
# company have high correlation with gross

# %%
# Scatter plot between budget vs gross
plt.scatter(x=df['budget'], y=df['gross'])
plt.title ("Budget vs Gross Earning")
plt.xlabel('Budget for Films')
plt.ylabel('Gross Earning')
plt.show()

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# plotting budget vs gross
sns.regplot(x= 'budget', y= 'gross', data= df, scatter_kws={"color":"red"}, line_kws= {"color":"blue"})
plt.show()

# %%
# correlation between budget and gross income
df[['budget','gross','runtime','score','votes','year']].corr(method = 'pearson') # Method =(pearson, kendell,spearman)
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.740263  0.318718  0.072155  0.439757  0.327961
# gross    0.740263  1.000000  0.275830  0.222709  0.614808  0.274395
# runtime  0.318718  0.275830  1.000000  0.414145  0.352331  0.075173
# score    0.072155  0.222709  0.414145  1.000000  0.474349  0.056506
# votes    0.439757  0.614808  0.352331  0.474349  1.000000  0.206161
# year     0.327961  0.274395  0.075173  0.056506  0.206161  1.000000

# %%
corr_matrix= df[['budget','gross','runtime','score','votes','year']].corr(method='pearson')

# %%
sns.heatmap(corr_matrix,annot = True)
plt.title('Correlation Matrix for numeric features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
df_numerize= df
for col in df_numerize.columns:
    if(df_numerize[col].dtype =='object'):
        df_numerize[col]= df_numerize[col].astype('category')
        df_numerize[col]= df_numerize[col].cat.codes

# %%
df.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1264
# 7445   388       5      0  2019       137    8.4   903000.0       105     514
# 3045  4912       5      6  1997       534    7.8  1100000.0       785    1264
# 6663  3645       5      0  2015       529    7.8   876000.0       768    1807
# 7244   389       5      0  2018       145    8.4   897000.0       105     514
#
#       star  country     budget       gross  company  runtime
# 5445  1534       47  237000000  2847246203     1382    162.0
# 7445  1470       47  356000000  2797501328      983    181.0
# 3045  1073       47  200000000  2201647264     1382    194.0
# 6663   356       47  245000000  2069521700      945    138.0
# 7244  1470       47  321000000  2048359754      983    149.0

# %%
df_numerize.info()
df_numerize.drop(['name'],axis = 1,inplace = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5424 entries, 5445 to 3203
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      5424 non-null   int16
#  1   rating    5424 non-null   int8
#  2   genre     5424 non-null   int8
#  3   year      5424 non-null   int64
#  4   released  5424 non-null   int16
#  5   score     5424 non-null   float64
#  6   votes     5424 non-null   float64
#  7   director  5424 non-null   int16
#  8   writer    5424 non-null   int16
#  9   star      5424 non-null   int16
#  10  country   5424 non-null   int8
#  11  budget    5424 non-null   int64
#  12  gross     5424 non-null   int64
#  13  company   5424 non-null   int16
#  14  runtime   5423 non-null   float64
# dtypes: float64(3), int16(6), int64(3), int8(3)
# memory usage: 376.1 KB

# %%
correlation_matrix = df.corr(method='pearson')
plt.figure(figsize=(15,15))
sns.heatmap(correlation_matrix,annot = True)

plt.title('Correlation Matrix for numeric features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
df_numerize.corr()
# Out:
#             rating     genre      year  released     score     votes  \
# rating    1.000000  0.147569  0.020085  0.018011  0.066335  0.006321
# genre     0.147569  1.000000 -0.073532  0.021952  0.035126 -0.135954
# year      0.020085 -0.073532  1.000000 -0.002033  0.056506  0.206161
# released  0.018011  0.021952 -0.002033  1.000000  0.046131  0.028810
# score     0.066335  0.035126  0.056506  0.046131  1.000000  0.474349
# votes     0.006321 -0.135954  0.206161  0.028810  0.474349  1.000000
# director  0.014381 -0.008507 -0.038676  0.002499  0.005294 -0.010499
# writer   -0.002966  0.016969 -0.025486  0.008480  0.012896 -0.005288
# star      0.009693  0.003026 -0.031559  0.015881  0.007683 -0.017377
# country   0.008061 -0.009185 -0.066833 -0.017225 -0.043207  0.041443
# budget   -0.203531 -0.368521  0.327961  0.019835  0.072155  0.439757
# gross    -0.181590 -0.244034  0.274395  0.008492  0.222709  0.614808
# company  -0.091306 -0.071608 -0.013187 -0.002539  0.021241  0.118850
# ...

# %%
correlation_matrix = df_numerize.corr()
corr_pairs = correlation_matrix.unstack()
corr_pairs
# Out:
# rating    rating      1.000000
#           genre       0.147569
#           year        0.020085
#           released    0.018011
#           score       0.066335
#           votes       0.006321
#           director    0.014381
#           writer     -0.002966
#           star        0.009693
#           country     0.008061
#           budget     -0.203531
#           gross      -0.181590
#           company    -0.091306
#           runtime     0.140886
# genre     rating      0.147569
#           genre       1.000000
#           year       -0.073532
#           released    0.021952
#           score       0.035126
#           votes      -0.135954
#           director   -0.008507
#           writer      0.016969
#           star        0.003026
#           country    -0.009185
#           budget     -0.368521
#           gross      -0.244034
#           company    -0.071608
#           runtime    -0.059367
# year      rating      0.020085
#           genre      -0.073532
# ...

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# budget    genre      -0.368521
# genre     budget     -0.368521
#           gross      -0.244034
# gross     genre      -0.244034
# budget    rating     -0.203531
# rating    budget     -0.203531
#           gross      -0.181590
# gross     rating     -0.181590
# votes     genre      -0.135954
# genre     votes      -0.135954
# rating    company    -0.091306
# company   rating     -0.091306
# year      genre      -0.073532
# genre     year       -0.073532
# company   genre      -0.071608
# genre     company    -0.071608
# year      country    -0.066833
# country   year       -0.066833
# genre     runtime    -0.059367
# runtime   genre      -0.059367
# country   score      -0.043207
# score     country    -0.043207
# budget    writer     -0.039307
# writer    budget     -0.039307
# year      director   -0.038676
# director  year       -0.038676
# writer    gross      -0.035842
# gross     writer     -0.035842
# country   runtime    -0.034514
# runtime   country    -0.034514
# ...

# %%
High_correlation = sorted_pairs[(sorted_pairs) >0.5]
High_correlation
# Out:
# gross     votes       0.614808
# votes     gross       0.614808
# budget    gross       0.740263
# gross     budget      0.740263
# rating    rating      1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# director  director    1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %%
# Outcome of the report
#  Votes and budget have highest correlation with gross earining.
